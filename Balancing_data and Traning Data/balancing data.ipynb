# %%
import pandas as pd 
ds= pd.read_csv(r"C:\Users\Rahul\Documents\Project\coords.csv")

# %%
coords
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 coords
#
# NameError: name 'coords' is not defined

# %%
coords= pd.DataFrame(columns=ds.columns)

# %%
coords
# Out:
# Empty DataFrame
# Columns: [class, x1, y1, z1, v1, x2, y2, z2, v2, x3, y3, z3, v3, x4, y4, z4, v4, x5, y5, z5, v5, x6, y6, z6, v6, x7, y7, z7, v7, x8, y8, z8, v8, x9, y9, z9, v9, x10, y10, z10, v10, x11, y11, z11, v11, x12, y12, z12, v12, x13, y13, z13, v13, x14, y14, z14, v14, x15, y15, z15, v15, x16, y16, z16, v16, x17, y17, z17, v17, x18, y18, z18, v18, x19, y19, z19, v19, x20, y20, z20, v20, x21, y21, z21, v21, x22, y22, z22, v22, x23, y23, z23, v23, x24, y24, z24, v24, x25, y25, z25, ...]
# Index: []
#
# [0 rows x 2005 columns]

# %%
hiding =ds[ds['class'].str.contains('hiding')]

# %%
hiding.head(154)
# Out:
#        class        x1        y1        z1        v1        x2        y2  \
# 80    hiding  0.453275  0.368424 -0.396520  0.999537  0.461705  0.343971
# 81    hiding  0.452496  0.368072 -0.336722  0.999549  0.461443  0.343816
# 82    hiding  0.451310  0.368129 -0.339404  0.999542  0.460750  0.344178
# 83    hiding  0.451085  0.368354 -0.351220  0.999525  0.460569  0.345021
# 84    hiding  0.450552  0.368523 -0.357476  0.999519  0.460269  0.345566
# ...      ...       ...       ...       ...       ...       ...       ...
# 1068  hiding  0.427662  0.380364 -0.360508  0.999366  0.438699  0.354844
# 1069  hiding  0.428129  0.381986 -0.358838  0.999330  0.438903  0.357317
# 1070  hiding  0.427298  0.387380 -0.333355  0.999248  0.437478  0.363306
# 1071  hiding  0.425474  0.389424 -0.301344  0.999131  0.435287  0.366213
# 1072  hiding  0.423758  0.389942 -0.301160  0.998823  0.431962  0.367904
#
#             z2        v2        x3  ...      z499  v499      x500      y500  \
# ...

# %%
coords = pd.concat([coords,hiding.head(154)],ignore_index=True)

# %%
coords
# Out:
#       class        x1        y1        z1        v1        x2        y2  \
# 0    hiding  0.453275  0.368424 -0.396520  0.999537  0.461705  0.343971
# 1    hiding  0.452496  0.368072 -0.336722  0.999549  0.461443  0.343816
# 2    hiding  0.451310  0.368129 -0.339404  0.999542  0.460750  0.344178
# 3    hiding  0.451085  0.368354 -0.351220  0.999525  0.460569  0.345021
# 4    hiding  0.450552  0.368523 -0.357476  0.999519  0.460269  0.345566
# ..      ...       ...       ...       ...       ...       ...       ...
# 149  hiding  0.427662  0.380364 -0.360508  0.999366  0.438699  0.354844
# 150  hiding  0.428129  0.381986 -0.358838  0.999330  0.438903  0.357317
# 151  hiding  0.427298  0.387380 -0.333355  0.999248  0.437478  0.363306
# 152  hiding  0.425474  0.389424 -0.301344  0.999131  0.435287  0.366213
# 153  hiding  0.423758  0.389942 -0.301160  0.998823  0.431962  0.367904
#
#            z2        v2        x3  ...      z499  v499      x500      y500  \
# ...

# %%
intrested =ds[ds['class'].str.contains('intrested')]

# %%
intrested
# Out:
#          class        x1        y1        z1        v1        x2        y2  \
# 10   intrested  0.468535  0.339969 -0.224025  0.999815  0.474880  0.316779
# 11   intrested  0.467394  0.339558 -0.226336  0.999813  0.474194  0.316532
# 12   intrested  0.467582  0.338759 -0.232674  0.999819  0.474249  0.315965
# 13   intrested  0.467179  0.337089 -0.243701  0.999828  0.473966  0.314595
# 14   intrested  0.440295  0.338072 -0.203467  0.999798  0.449410  0.315266
# ..         ...       ...       ...       ...       ...       ...       ...
# 801  intrested  0.368601  0.315818 -0.054900  0.999339  0.381013  0.285457
# 802  intrested  0.370314  0.315598 -0.046374  0.999372  0.382613  0.285144
# 803  intrested  0.373644  0.316293 -0.085903  0.999404  0.386510  0.285902
# 804  intrested  0.374017  0.322179 -0.045937  0.999423  0.386514  0.292784
# 805  intrested  0.375524  0.325255 -0.059977  0.999452  0.387168  0.296665
#
# ...

# %%
coords = pd.concat([coords,intrested.head(154)],ignore_index=True)

# %%
coords
# Out:
#          class        x1        y1        z1        v1        x2        y2  \
# 0       hiding  0.453275  0.368424 -0.396520  0.999537  0.461705  0.343971
# 1       hiding  0.452496  0.368072 -0.336722  0.999549  0.461443  0.343816
# 2       hiding  0.451310  0.368129 -0.339404  0.999542  0.460750  0.344178
# 3       hiding  0.451085  0.368354 -0.351220  0.999525  0.460569  0.345021
# 4       hiding  0.450552  0.368523 -0.357476  0.999519  0.460269  0.345566
# ..         ...       ...       ...       ...       ...       ...       ...
# 303  intrested  0.438525  0.235578 -0.322075  0.999882  0.451770  0.207752
# 304  intrested  0.478017  0.227757 -0.321923  0.999889  0.487541  0.200746
# 305  intrested  0.510730  0.226666 -0.395631  0.999862  0.519883  0.198821
# 306  intrested  0.515626  0.227076 -0.379597  0.999870  0.526254  0.198645
# 307  intrested  0.530091  0.223615 -0.373026  0.999876  0.540012  0.194888
#
# ...

# %%
lying=ds[ds['class'].str.contains('lying')]

# %%
lying
# Out:
#      class        x1        y1        z1        v1        x2        y2  \
# 29   lying  0.443955  0.538506 -0.312392  0.998032  0.450050  0.515250
# 30   lying  0.439945  0.538329 -0.284545  0.997879  0.446596  0.515016
# 31   lying  0.425373  0.538920 -0.257692  0.997850  0.432919  0.515189
# 32   lying  0.409427  0.540216 -0.217728  0.997754  0.416190  0.516543
# 33   lying  0.402022  0.544125 -0.231390  0.997458  0.409694  0.520771
# ..     ...       ...       ...       ...       ...       ...       ...
# 949  lying  0.303965  0.560947 -0.173113  0.998638  0.304851  0.539194
# 950  lying  0.307664  0.560631 -0.174782  0.998704  0.308318  0.538857
# 951  lying  0.317159  0.560228 -0.175808  0.998728  0.318446  0.538239
# 952  lying  0.325002  0.557276 -0.182649  0.998771  0.327401  0.534703
# 953  lying  0.330809  0.555446 -0.200695  0.998795  0.333448  0.532508
#
#            z2        v2        x3  ...      z499  v499      x500      y500  \
# ...

# %%
coords = pd.concat([coords,lying.head(154)],ignore_index=True)

# %%
coords
# Out:
#       class        x1        y1        z1        v1        x2        y2  \
# 0    hiding  0.453275  0.368424 -0.396520  0.999537  0.461705  0.343971
# 1    hiding  0.452496  0.368072 -0.336722  0.999549  0.461443  0.343816
# 2    hiding  0.451310  0.368129 -0.339404  0.999542  0.460750  0.344178
# 3    hiding  0.451085  0.368354 -0.351220  0.999525  0.460569  0.345021
# 4    hiding  0.450552  0.368523 -0.357476  0.999519  0.460269  0.345566
# ..      ...       ...       ...       ...       ...       ...       ...
# 457   lying  0.439945  0.538329 -0.284545  0.997879  0.446596  0.515016
# 458   lying  0.425373  0.538920 -0.257692  0.997850  0.432919  0.515189
# 459   lying  0.409427  0.540216 -0.217728  0.997754  0.416190  0.516543
# 460   lying  0.402022  0.544125 -0.231390  0.997458  0.409694  0.520771
# 461   lying  0.383929  0.543884 -0.222466  0.997452  0.391543  0.520471
#
#            z2        v2        x3  ...      z499  v499      x500      y500  \
# ...

# %%
offend=ds[ds['class'].str.contains('offend')]

# %%
offend
# Out:
#       class        x1        y1        z1        v1        x2        y2  \
# 159  offend  0.488185  0.278939 -0.248118  0.995648  0.498567  0.246777
# 160  offend  0.484302  0.278902 -0.261309  0.995558  0.496842  0.246790
# 161  offend  0.478161  0.279444 -0.265386  0.995679  0.491761  0.247859
# 162  offend  0.463769  0.287025 -0.227215  0.995794  0.479217  0.255804
# 163  offend  0.452163  0.295139 -0.225614  0.996009  0.467428  0.264950
# ..      ...       ...       ...       ...       ...       ...       ...
# 614  offend  0.485025  0.303644 -0.224330  0.998738  0.497768  0.275262
# 615  offend  0.485687  0.303805 -0.228904  0.998707  0.498299  0.275387
# 616  offend  0.485324  0.304239 -0.221344  0.998758  0.497972  0.275489
# 617  offend  0.487048  0.304685 -0.221357  0.998768  0.498924  0.275748
# 618  offend  0.487402  0.304828 -0.224296  0.998813  0.499319  0.275815
#
#            z2        v2        x3  ...      z499  v499      x500      y500  \
# ...

# %%
coords = pd.concat([coords,offend.head(154)],ignore_index=True)

# %%
coords
# Out:
#       class        x1        y1        z1        v1        x2        y2  \
# 0    hiding  0.453275  0.368424 -0.396520  0.999537  0.461705  0.343971
# 1    hiding  0.452496  0.368072 -0.336722  0.999549  0.461443  0.343816
# 2    hiding  0.451310  0.368129 -0.339404  0.999542  0.460750  0.344178
# 3    hiding  0.451085  0.368354 -0.351220  0.999525  0.460569  0.345021
# 4    hiding  0.450552  0.368523 -0.357476  0.999519  0.460269  0.345566
# ..      ...       ...       ...       ...       ...       ...       ...
# 611  offend  0.481926  0.348073 -0.198587  0.997696  0.495132  0.323891
# 612  offend  0.480626  0.348047 -0.205249  0.997827  0.493605  0.324260
# 613  offend  0.480186  0.348390 -0.208850  0.997926  0.493234  0.324100
# 614  offend  0.479900  0.349724 -0.213110  0.998004  0.492757  0.325505
# 615  offend  0.476443  0.349487 -0.210616  0.998111  0.489207  0.324982
#
#            z2        v2        x3  ...      z499  v499      x500      y500  \
# ...

# %%
sad=ds[ds['class'].str.contains('sad')]
sad
# Out:
#      class        x1        y1        z1        v1        x2        y2  \
# 1194   sad  0.429252  0.432872 -0.472293  0.995794  0.435541  0.406713
# 1195   sad  0.427777  0.432592 -0.390593  0.996110  0.434171  0.406598
# 1196   sad  0.427214  0.432859 -0.394045  0.996458  0.433778  0.406913
# 1197   sad  0.432747  0.433031 -0.477409  0.996711  0.438900  0.407384
# 1198   sad  0.448183  0.432989 -0.428241  0.997143  0.454275  0.409751
# ...    ...       ...       ...       ...       ...       ...       ...
# 1410   sad  0.436550  0.409347 -0.574910  0.999330  0.447944  0.380418
# 1411   sad  0.439439  0.407786 -0.569496  0.999265  0.450952  0.379011
# 1412   sad  0.440619  0.407015 -0.624054  0.999239  0.452335  0.378221
# 1413   sad  0.441729  0.403806 -0.595018  0.999190  0.453610  0.374774
# 1414   sad  0.444991  0.400851 -0.647265  0.999164  0.456987  0.371664
#
#             z2        v2        x3  ...      z499  v499      x500      y500  \
# ...

# %%
coords = pd.concat([coords,sad.head(154)],ignore_index=True)

# %%
coords
# Out:
#       class        x1        y1        z1        v1        x2        y2  \
# 0    hiding  0.453275  0.368424 -0.396520  0.999537  0.461705  0.343971
# 1    hiding  0.452496  0.368072 -0.336722  0.999549  0.461443  0.343816
# 2    hiding  0.451310  0.368129 -0.339404  0.999542  0.460750  0.344178
# 3    hiding  0.451085  0.368354 -0.351220  0.999525  0.460569  0.345021
# 4    hiding  0.450552  0.368523 -0.357476  0.999519  0.460269  0.345566
# ..      ...       ...       ...       ...       ...       ...       ...
# 765     sad  0.465263  0.435876 -0.476086  0.999621  0.476505  0.409464
# 766     sad  0.470219  0.433806 -0.437982  0.999625  0.481616  0.408512
# 767     sad  0.479868  0.433732 -0.373646  0.999611  0.492114  0.408326
# 768     sad  0.481627  0.433625 -0.441812  0.999616  0.493515  0.408199
# 769     sad  0.481238  0.433545 -0.368790  0.999632  0.492956  0.408541
#
#            z2        v2        x3  ...      z499  v499      x500      y500  \
# ...

# %%
stressed=ds[ds['class'].str.contains('stressed')]
stressed
# Out:
#          class        x1        y1        z1        v1        x2        y2  \
# 1415  stressed  0.455925  0.388429 -0.383786  0.999953  0.466258  0.367981
# 1416  stressed  0.456939  0.388483 -0.374402  0.999950  0.466792  0.367354
# 1417  stressed  0.457457  0.388485 -0.366275  0.999943  0.467216  0.367118
# 1418  stressed  0.459088  0.388523 -0.388771  0.999938  0.468542  0.367050
# 1419  stressed  0.460564  0.388519 -0.387866  0.999932  0.469606  0.366851
# ...        ...       ...       ...       ...       ...       ...       ...
# 1564  stressed  0.422660  0.349638 -0.192373  0.999483  0.439922  0.336226
# 1565  stressed  0.433039  0.349340 -0.193830  0.999530  0.449277  0.336305
# 1566  stressed  0.434484  0.350722 -0.197292  0.999571  0.450814  0.337715
# 1567  stressed  0.436627  0.356859 -0.216087  0.999608  0.452512  0.342094
# 1568  stressed  0.436343  0.358278 -0.202768  0.999641  0.452267  0.343195
#
# ...

# %%
coords = pd.concat([coords,stressed.head(154)],ignore_index=True)

# %%
coords
# Out:
#         class        x1        y1        z1        v1        x2        y2  \
# 0      hiding  0.453275  0.368424 -0.396520  0.999537  0.461705  0.343971
# 1      hiding  0.452496  0.368072 -0.336722  0.999549  0.461443  0.343816
# 2      hiding  0.451310  0.368129 -0.339404  0.999542  0.460750  0.344178
# 3      hiding  0.451085  0.368354 -0.351220  0.999525  0.460569  0.345021
# 4      hiding  0.450552  0.368523 -0.357476  0.999519  0.460269  0.345566
# ..        ...       ...       ...       ...       ...       ...       ...
# 919  stressed  0.422660  0.349638 -0.192373  0.999483  0.439922  0.336226
# 920  stressed  0.433039  0.349340 -0.193830  0.999530  0.449277  0.336305
# 921  stressed  0.434484  0.350722 -0.197292  0.999571  0.450814  0.337715
# 922  stressed  0.436627  0.356859 -0.216087  0.999608  0.452512  0.342094
# 923  stressed  0.436343  0.358278 -0.202768  0.999641  0.452267  0.343195
#
#            z2        v2        x3  ...      z499  v499      x500      y500  \
# ...

# %%
victory=ds[ds['class'].str.contains('victory')]
victory
# Out:
#        class        x1        y1        z1        v1        x2        y2  \
# 0    victory  0.452012  0.360913 -0.170280  0.999959  0.462480  0.337278
# 1    victory  0.451480  0.358527 -0.173353  0.999960  0.462244  0.336359
# 2    victory  0.451487  0.358240 -0.175958  0.999961  0.462246  0.336393
# 3    victory  0.451559  0.358350 -0.179712  0.999963  0.462222  0.336441
# 4    victory  0.456310  0.359487 -0.191262  0.999966  0.468561  0.337841
# ..       ...       ...       ...       ...       ...       ...       ...
# 294  victory  0.473228  0.362718 -0.210259  0.999991  0.482711  0.342563
# 295  victory  0.473221  0.362931 -0.208282  0.999991  0.482656  0.342796
# 296  victory  0.473255  0.363067 -0.199662  0.999990  0.482651  0.342911
# 297  victory  0.473289  0.363096 -0.204755  0.999989  0.482660  0.342933
# 298  victory  0.473463  0.363157 -0.205503  0.999989  0.482763  0.342981
#
#            z2        v2        x3  ...      z499  v499      x500      y500  \
# ...

# %%
coords = pd.concat([coords,victory.head(154)],ignore_index=True)

# %%
coords
# Out:
#         class        x1        y1        z1        v1        x2        y2  \
# 0      hiding  0.453275  0.368424 -0.396520  0.999537  0.461705  0.343971
# 1      hiding  0.452496  0.368072 -0.336722  0.999549  0.461443  0.343816
# 2      hiding  0.451310  0.368129 -0.339404  0.999542  0.460750  0.344178
# 3      hiding  0.451085  0.368354 -0.351220  0.999525  0.460569  0.345021
# 4      hiding  0.450552  0.368523 -0.357476  0.999519  0.460269  0.345566
# ...       ...       ...       ...       ...       ...       ...       ...
# 1073  victory  0.450391  0.363295 -0.182292  0.999957  0.460558  0.338756
# 1074  victory  0.452012  0.360913 -0.170280  0.999959  0.462480  0.337278
# 1075  victory  0.451480  0.358527 -0.173353  0.999960  0.462244  0.336359
# 1076  victory  0.451487  0.358240 -0.175958  0.999961  0.462246  0.336393
# 1077  victory  0.451559  0.358350 -0.179712  0.999963  0.462222  0.336441
#
#             z2        v2        x3  ...      z499  v499      x500      y500  \
# ...

# %%
coords.to_csv('ncoords.csv')

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
dp=coords

# %%
df=dp.sample(n=1078)
df
# Out:
#          class        x1        y1        z1        v1        x2        y2  \
# 749        sad  0.466815  0.420868 -0.637609  0.999681  0.478648  0.393304
# 667        sad  0.455539  0.432097 -0.515970  0.999197  0.462791  0.408650
# 1009   victory  0.464962  0.237892 -0.210462  0.999887  0.474199  0.215186
# 5       hiding  0.450541  0.368767 -0.367058  0.999517  0.460241  0.345758
# 634        sad  0.449874  0.425507 -0.474883  0.998733  0.457737  0.402210
# ...        ...       ...       ...       ...       ...       ...       ...
# 1008   victory  0.464986  0.241801 -0.312871  0.999879  0.474192  0.215855
# 1036   victory  0.507753  0.394156 -0.291032  0.999691  0.515692  0.369532
# 53      hiding  0.452023  0.369979 -0.365159  0.999555  0.461359  0.346742
# 831   stressed  0.490173  0.376087 -0.339970  0.999737  0.502011  0.359296
# 12      hiding  0.451584  0.369628 -0.382032  0.999539  0.460842  0.346281
#
# ...

# %%
X = df.drop('class', axis=1) # features
y = df['class'] # target value

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1234)

# %%
from sklearn.pipeline import make_pipeline 
from sklearn.preprocessing import StandardScaler 
from sklearn.ensemble import RandomForestClassifier,GradientBoostingClassifier
from sklearn import svm

# %%
pipelines = {'rf':make_pipeline(StandardScaler(), RandomForestClassifier())}

# %%
fit_models = {}
for algo, pipeline in pipelines.items():
    model = pipeline.fit(X_train, y_train)
    fit_models[algo] = model

# %%
fit_models['rf'].predict(X_test)
# Out:
# array(['sad', 'stressed', 'intrested', 'offend', 'hiding', 'victory',
#        'lying', 'hiding', 'lying', 'intrested', 'offend', 'sad',
#        'stressed', 'stressed', 'lying', 'stressed', 'intrested', 'lying',
#        'intrested', 'intrested', 'sad', 'lying', 'lying', 'victory',
#        'hiding', 'hiding', 'sad', 'hiding', 'hiding', 'hiding', 'lying',
#        'stressed', 'lying', 'victory', 'victory', 'stressed', 'hiding',
#        'victory', 'stressed', 'intrested', 'intrested', 'sad', 'lying',
#        'victory', 'stressed', 'hiding', 'sad', 'victory', 'sad',
#        'victory', 'hiding', 'offend', 'victory', 'sad', 'offend',
#        'stressed', 'sad', 'hiding', 'stressed', 'sad', 'sad', 'offend',
#        'lying', 'sad', 'lying', 'intrested', 'sad', 'stressed', 'victory',
#        'victory', 'victory', 'hiding', 'victory', 'lying', 'hiding',
#        'sad', 'victory', 'intrested', 'sad', 'lying', 'hiding', 'sad',
# ...

# %%
from sklearn.metrics import accuracy_score # Accuracy metrics 
import pickle

# %%
for algo, model in fit_models.items():
    yhat = model.predict(X_test)
    print(algo, accuracy_score(y_test, yhat))
# Out:
# rf 1.0

# %%
with open('body_language.pkl', 'wb') as f:
    pickle.dump(fit_models['rf'], f)
